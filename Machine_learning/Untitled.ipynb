# %%
import pandas as pd

# %%
df = pd.read_csv(
    r"C:\Users\MEPZ\Downloads\CDAC-MPEZ\C---DAC-MEPZ\DAY 4(19.02.2026)\chipotle.tsv",
    sep="\t"
)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   porder_id           4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   str
#  3   choice_description  3376 non-null   str
#  4   item_price          4622 non-null   str
# dtypes: int64(2), str(3)
# memory usage: 180.7 KB

# %%
print(dir())
# Out:
# ['In', 'Out', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__session__', '__spec__', '_dh', '_i', '_i1', '_i2', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'df', 'exit', 'get_ipython', 'open', 'pd', 'quit']

# %%
cd "C:\Users\MEPZ\Downloads\CDAC-MPEZ\C---DAC-MEPZ\DAY 4(19.02.2026)"
# Out:
# C:\Users\MEPZ\Downloads\CDAC-MPEZ\C---DAC-MEPZ\DAY 4(19.02.2026)

# %%
pwd
# Out:
# 'C:\\Users\\MEPZ\\Downloads\\CDAC-MPEZ\\C---DAC-MEPZ\\DAY 4(19.02.2026)'

# %%
df
# Out:
#       porder_id  quantity                              item_name  \
# 0             1         1           Chips and Fresh Tomato Salsa
# 1             1         1                                   Izze
# 2             1         1                       Nantucket Nectar
# 3             1         1  Chips and Tomatillo-Green Chili Salsa
# 4             2         2                           Chicken Bowl
# ...         ...       ...                                    ...
# 4617       1833         1                          Steak Burrito
# 4618       1833         1                          Steak Burrito
# 4619       1834         1                     Chicken Salad Bowl
# 4620       1834         1                     Chicken Salad Bowl
# 4621       1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.bar(item_agg['item_name'], item_agg['item_total'])

plt.xlabel('Item Name')
plt.ylabel('Total Sales Amount')
plt.title('Item-wise Sales Data')

plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 import matplotlib.pyplot as plt
#       3 plt.figure(figsize=(10, 5))
# ----> 4 plt.bar(item_agg['item_name'], item_agg['item_total'])
#       6 plt.xlabel('Item Name')
#       7 plt.ylabel('Total Sales Amount')
#
# NameError: name 'item_agg' is not defined
